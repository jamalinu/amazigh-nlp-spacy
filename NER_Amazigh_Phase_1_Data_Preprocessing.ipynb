# %% [markdown]
# <a href="https://colab.research.google.com/github/jamalinu/amazigh-nlp-spacy/blob/main/NER_Amazigh_Phase_1_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook focuses on transforming raw linguistic annotations into high-performance binary data (DocBin) to train a custom NER model for the Amazigh language.
#
# Converting multilingual raw text into spaCy's Binary format (DocBin) for optimized training.

# %%
import spacy
from spacy.tokens import DocBin
from tqdm import tqdm

# %%
TRAIN_DATA = [
("Nekk d amezdugh n Nador.", {"entities": [(17, 22, "LOC")]}),
("Ait Sidal tzeddeg g Arrif.", {"entities": [(0, 9, "LOC"), (21, 26, "LOC")]}),
("Abdelkrim el Khattabi d amjahid n Arrif.", {"entities": [(0, 21, "PER"), (34, 39, "LOC")]}),
("Massinissa t-yessers ugellid n Rom.", {"entities": [(0, 10, "PER"), (31, 34, "LOC")]}),
("ⵎⴰⵙⵉⵏⵉⵙⴰ ⴷ ⴰⴳⴻⵍⵍⵉⴷ ⴰⵎⴰⵣⵉⵖ.", {"entities": [(0, 8, "PER")]}),
("ⴰⵍⵃⵓⵙⵉⵎⴰ ⵜⴻⵣⴷⴷⴻⴳ ⴳ ⴰⵔⵔⵉⴼ.", {"entities": [(0, 8, "LOC"), (20, 25, "LOC")]}),
("UNESCO t-ḥader ɣef tgemmi n tmaziɣt.", {"entities": [(0, 6, "ORG")]}),
]

# %%
nlp = spacy.blank("xx")
db = DocBin()

for text, annot in tqdm(TRAIN_DATA):
    doc = nlp.make_doc(text)
    ents = []
    for start, end, label in annot["entities"]:
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is not None:
            ents.append(span)
    doc.ents = ents
    db.add(doc)
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 2411.71it/s]

# %%
db.to_disk("train.spacy")
print("✅ ¡Archivo train.spacy creado!")
# Out:
# ✅ ¡Archivo train.spacy creado!
