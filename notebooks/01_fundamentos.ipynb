# %% [markdown]
# # Amazigh NLP Pipeline - Fundamentos spaCy
#
# **Autor:** Tu nombre
#
# **Descripcion:** Primer pipeline NLP para tamazight construido por hablante nativo

# %%
# !pip install spacy -q
# !python -m spacy download es_core_news_lg -q
print('Instalacion completada')
