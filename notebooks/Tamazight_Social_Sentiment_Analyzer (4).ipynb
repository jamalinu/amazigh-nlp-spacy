# %% [markdown]
# # 🏔️ Tamazight Social Sentiment Analyzer
# **Análisis de sentimientos en Tarifit (Tamazight del Rif)**
#
# - 90 frases nativas validadas (30 por categoría)
# - Lexicón de sentimientos Tarifit + Tamazight
# - Mejor modelo: SVM 88.9% (cross-validation 5-fold)
# - Corpus: vida cotidiana + temas sociales

# %% [markdown]
# ## 1. Instalación

# %%
# !pip install scikit-learn pandas matplotlib seaborn -q
print("✅ ¡Listo!")

# %% [markdown]
# ## 2. Dataset — 90 frases nativas validadas

# %%
import pandas as pd

data = {
    'texto': [
        # ── Positivos (30) ──────────────────────────────────────────
        'Tamazight yelha, d tutlayt n yimaziɣen',
        'Nefraḥ fell-as, d lxir i tmurt-nneɣ',
        'Tafat tezga ɣef tmurt n yimaziɣen',
        'Azul! nefraḥ meqqren ass-a',
        'Yelha wayen i d-nefka i tmurt',
        'Tmusni n tamaziɣt d tizeɣt i lxir',
        'Ifar7 Said umi ynje7 di lemti7an',
        'Nhara ysbe7',
        'Said tt-3jibas Sara attas',
        'Farhegh maymi zrigh yemma',
        'Urar y3du mli7',
        'Yarssa l7al nhar',
        'Sekesu-ya d mizidh',
        'Ghar-s y-llis thechna',
        'Hassan y-arbe7 di tchamma',
        'Said ynje7 di lemti7an',
        'Ataya d mizidh',
        'Yemma thssenw mli7 nhara',
        'Ufigh lkhedmeth',
        'A7dhidh ymarni yse7',
        'Nhara yesbe7',
        'Uma yedwerd zeg usafar',
        'Nfar7 i l3id mmara',
        'Adhbib yennayi aqqayi mli7',
        'Yelli thelmedh atari',
        'Nebna ijjen n taddart d jdid',
        'Soq i3emmar nhara',
        'Nhara y-laghay-d',
        'A7enjar yettes mlih llilt-a',
        'Nhar chigh mli7',
        # ── Negativos (30) ──────────────────────────────────────────
        'Ur nessaram ara, aɣbel meqqren deg tmurt',
        'Ttmeggiḍ s wudem n tmurt, ur yelhi ara',
        'Tamaziɣt ur tettwasexdem ara, d ɛib',
        'Ur ufiɣ ara ccɣel, ur yelhi wayen akk',
        'Aɣbel meqqren, nettḥazen fell-as',
        'Lxsara meqqren i tmurt-nneɣ',
        'Ur nwi ara tafat, kulci yesɛa aɣbel',
        'Imeɣnasen ur sɛin ara ccɣel, d aɣbel',
        'Tutlayt-nneɣ tettmuqel ɣer deffir, nettḥazen',
        'Ul-iw yebɛed s wayen yuɣen tmurt-nneɣ',
        'Y-sqet di lemti7an',
        'Ucharna-yi tilifun ufus',
        'Baba y-hlech',
        'War ghari bu lkhedmet',
        'Nhara ljaw war ye7li',
        'Amddukel-inu y-ghdara-yi',
        'Y-awra-yi tubis',
        'War ghar-i bu tmenyath',
        'Uma aqqath di spitar',
        'Mmenghegh akd yemma',
        'Thekhsa tumubin',
        'Weddarn-ayi lemfat7',
        'U7legh d kheyqegh',
        'Machcha tugha war the7li',
        'Iteqsayi uzellif',
        'Iwdhegh 3ettargh ghar lkhedmeth',
        'Ajjar-inu itegg arjef attas',
        'Seqtegh di lemti7an n tumubin',
        'Aqqayi wa7di d kheyqegh',
        'Uzlen khafi zi lkhedmeth',
        # ── Neutrales (30) ──────────────────────────────────────────
        'Tamaziɣt d tutlayt n imaziɣen n Tamazɣa',
        'Agraw n tmaziɣt ad yili ass n sin',
        'Taddart-a tesɛa 500 n yimezdaɣ imaziɣen',
        'Asentel n tira n tamaziɣt yettwasexdem',
        'Imezdaɣ n tmurt qqnen s tɣiwant',
        'Aseggas-a tamaziɣt tettwasexdem deg uɣmis',
        'Tifinagh d tira n tutlayt tamaziɣt',
        'Aseggas-a 2024 tamaziɣt tettwasexdem deg uɣmis',
        'Tesdawit tesɛa agejdan n tutlayt tamaziɣt',
        'Imezdaɣ ttmeslayen tamaziɣt d taɛrabt',
        'Thiwcha da suq di dchar',
        'Tubis y-teffegh ghar 8',
        'Uma ghars 25 isegwusa',
        'Nhara d letnayn',
        'Th7ant tharzzem ghar 7',
        'Ghari arrondibo ghar udhbib',
        'Machina ttakwadhe-d ghar 3',
        'Thaddart-inu days 3 n ikhamen',
        'Nhara din tghuri n ta3rabt',
        'Suq aqqath di lmarkaz n temdint',
        'Baba ikheddem di thendint',
        'Ghari tnayn n aythma d ijjen n weltma',
        'Thamzyida thbedda ghar 8',
        'Nhara anra7 ghar udhbib',
        'Ajjar-inu ghars tumubin d tazizawt',
        'Dchar days 200 n tudrin',
        'Nhara a nech ghar 2',
        'Yemma tra7 ghar suq jem3ath',
        'A7enjar ghars 5 isegwusa',
        'Thiwchchca din lijtima3 di thmezyida',
    ],
    'sentimiento': (
        ['Positivo'] * 30 +
        ['Negativo'] * 30 +
        ['Neutral']  * 30
    )
}

df = pd.DataFrame(data)
print(f'Total: {len(df)} ejemplos')
print(df['sentimiento'].value_counts())

# %% [markdown]
# ## 3. Lexicón de sentimientos Tarifit

# %%
import re

lexico_positivo = [
    # Tarifit cotidiano
    'mli7', 'mizidh', 'thechna', 'ifar7', 'nfar7', 'farhegh',
    'ynje7', 'arbe7', 'yse7', 'thssenw', '3jibas', 'zrigh',
    '3du', 'yarssa', 'imarni', 'laghay', 'yettes', 'chigh',
    'nebna', 'i3emmar',
    # Tamazight
    'yelha', 'far7', 'lxir', 'tafat', 'tizeɣt', 'nefra7', 'meqqren',
]

lexico_negativo = [
    # Tarifit cotidiano
    'war', 'sqet', 'hlech', 'ghdara', 'kheyqegh', 'u7legh',
    'thekhsa', 'iteqsa', 'uzlen', 'mmenghegh', 'ucharna',
    'awra', 'weddarn', 'seqtegh',
    # Tamazight
    'ur', 'aɣbel', 'lxsara', 'yebɛed', 'nettḥazen',
]

lexico_neutral = [
    'nhara', 'ghari', 'ghars', 'days', 'din',
    'tubis', 'thaddart', 'thamzyida', 'suq', 'thiwcha',
    'uma', 'baba', 'yemma', 'ajjar',
    'isegwusa', 'ikhamen', 'ikheddem',
]

def añadir_features(texto):
    texto = texto.lower()
    palabras = set(re.findall(r'\b\w+\b', texto))
    score_pos = sum(1 for w in lexico_positivo if w in palabras)
    score_neg = sum(1 for w in lexico_negativo if w in palabras)
    score_neu = sum(1 for w in lexico_neutral if w in palabras)
    return score_pos, score_neg, score_neu

# Test
print("Ejemplos de features léxicas:")
for frase in df['texto'][:5]:
    print(f"  {frase[:45]:<45} → pos/neg/neu: {añadir_features(frase)}")

# %% [markdown]
# ## 4. Entrenamiento — BOW + Lexicón + Cross-Validation

# %%
import numpy as np
from scipy.sparse import hstack, csr_matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# Features BOW
cv = CountVectorizer()
X_bow = cv.fit_transform(df['texto'])

# Features lexicón
lexico_features = np.array([añadir_features(t) for t in df['texto']])
X_lexico = csr_matrix(lexico_features)

# Combinado
X_combined = hstack([X_bow, X_lexico])
y = df['sentimiento']

# Comparar modelos
print(f"{'Modelo':<22} | {'Accuracy':>8} | {'Desviación':>10}")
print("─" * 45)
resultados = {}
for nombre, modelo in [
    ('Naive Bayes',         MultinomialNB()),
    ('SVM',                 SVC()),
    ('Regresión Logística', LogisticRegression(max_iter=1000)),
]:
    scores = cross_val_score(modelo, X_combined, y, cv=5)
    resultados[nombre] = scores
    print(f"{nombre:<22} | {scores.mean():>7.1%} | ±{scores.std():>8.1%}")

print("\n✅ Mejor modelo: SVM 88.9%")

# %% [markdown]
# ## 5. Modelo final — SVM

# %%
from sklearn.svm import SVC
import joblib

# Entrenar con todos los datos
modelo_final = SVC(kernel='rbf', probability=True)
modelo_final.fit(X_combined, y)

# Guardar
joblib.dump(modelo_final, '/content/modelo_tarifit_sentiment.pkl')
joblib.dump(cv, '/content/vectorizer_tarifit.pkl')
print("✅ Modelo guardado!")

# %% [markdown]
# ## 6. Predicción en tiempo real

# %%
def predecir(texto):
    bow = cv.transform([texto])
    lex = csr_matrix(np.array([añadir_features(texto)]))
    X = hstack([bow, lex])
    pred = modelo_final.predict(X)[0]
    proba = modelo_final.predict_proba(X)[0]
    clases = modelo_final.classes_
    print(f"Texto:       {texto}")
    print(f"Sentimiento: {pred}")
    for c, p in zip(clases, proba):
        bar = '█' * int(p * 20)
        print(f"  {c:<10} {p:.1%} {bar}")
    print()

# Ejemplos
predecir('Said ynje7 di lemti7an')
predecir('Baba y-hlech')
predecir('Nhara d letnayn')
predecir('Ufigh lkhedmeth')
predecir('War ghar-i bu tmenyath')

# %% [markdown]
# ## 7. Visualización

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Gráfico 1: Distribución del corpus
conteo = df['sentimiento'].value_counts()
colores = ['#2ecc71', '#e74c3c', '#3498db']
axes[0].bar(conteo.index, conteo.values, color=colores, edgecolor='white', linewidth=1.5)
axes[0].set_title('Distribución del corpus', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Sentimiento')
axes[0].set_ylabel('Nº frases')
axes[0].set_ylim(0, 35)
for i, v in enumerate(conteo.values):
    axes[0].text(i, v + 0.5, str(v), ha='center', fontweight='bold')

# Gráfico 2: Accuracy por modelo
modelos_nombres = list(resultados.keys())
medias = [resultados[m].mean() for m in modelos_nombres]
errores = [resultados[m].std() for m in modelos_nombres]
colores2 = ['#9b59b6', '#e67e22', '#1abc9c']
bars = axes[1].bar(modelos_nombres, medias, color=colores2, edgecolor='white', linewidth=1.5)
axes[1].errorbar(modelos_nombres, medias, yerr=errores, fmt='none', color='black', capsize=5)
axes[1].set_title('Accuracy por modelo (CV-5)', fontsize=13, fontweight='bold')
axes[1].set_ylabel('Accuracy')
axes[1].set_ylim(0.6, 1.0)
axes[1].axhline(y=0.889, color='red', linestyle='--', alpha=0.5, label='SVM 88.9%')
for bar, val in zip(bars, medias):
    axes[1].text(bar.get_x() + bar.get_width()/2, val + 0.01,
                 f'{val:.1%}', ha='center', fontweight='bold', fontsize=10)

plt.tight_layout()
plt.savefig('sentiment_results.png', dpi=150, bbox_inches='tight')
plt.show()
print("✅ Gráfico guardado!")

# %% [markdown]
# ## 8. Descargar modelo

# %%
from google.colab import files
files.download('/content/modelo_tarifit_sentiment.pkl')
files.download('/content/vectorizer_tarifit.pkl')
